# %% [markdown]
# # Grafici di funzioni di due variabili con python
#
# Impariamo a disegnare con python i grafici di funzioni di due variabili, cioè di
# funzioni $f:A \to \mathbb R$, dove $A$ è un sottoinsieme di $\mathbb R^2$.
#
# Ricordiamo che il grafico di una funzione di questo tipo è un sottoinsieme di $\mathbb R^3$ e quindi per
# rappresentarlo abbiamo bisogno di un sistema di coordinate tridimensionale.
# Più precisamente il grafico di $f$ è l'insieme
# $$
# \left\{
# (x, y, z) \in A \times \mathbb R:\, z = f(x, y)
# \right\}.
# $$
# Come esempio rappresentiamo il grafico delle seguenti $3$ funzioni, tutte definite su $A=\mathbb R^2 \setminus \{0\}$:
# $$
# f_1(x, y) = \frac{x^2}{\sqrt{x^2 + y^2}}
# \qquad
# f_2(x, y) = \frac{x}{\sqrt{x^2 + y^2}}
# \qquad
# f_3(x, y) = \frac{x^2 y}{\sqrt{x^4 + y^2}}.
# $$
#
#
# Per prima cosa carichiamo le librerie numpy e matplotlib:

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %% [markdown]
# Impostiamo la visualizzazione interattiva esterna

# %%
# %matplotlib qt5
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/lib/python3/dist-packages/matplotlib/backends/qt_compat.py in <module>
#     197     try:
# --> 198         from PySide import QtCore, QtGui, __version__, __version_info__
#     199     except ImportError:
#
# ModuleNotFoundError: No module named 'PySide'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-64557277dbff> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt5')
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
# ...

# %% [markdown]
# Definiamo le funzioni di due variabili da disegnare

# %%
def fun_1(x, y):
    return x**2 / np.sqrt(x**2 + y**2)

def fun_2(x, y):
    return x / np.sqrt(x**2 + y**2)

def fun_3(x, y):
    return x**2 * y / (x**4 + y**2)

# %% [markdown]
# ## Disegnamo la funzione
#
# Bisogna impostare sia la funzione desiderata che il range sia per la $x$ che per la $y$.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = np.arange(-3, 3, 0.05)
y = np.arange(-3, 3, 0.05)
X, Y = np.meshgrid(x, y)
Z = fun_3(X, Y)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %% [markdown]
# Alla fine ricordiamoci di chiudere la figura

# %%
plt.close()
